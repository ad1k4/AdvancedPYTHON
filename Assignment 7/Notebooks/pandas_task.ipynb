# %%
# !pip3 install pandas
import pandas as pd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.1 MB/s  0:00:091.1 MB/s eta 0:00:01:020m
# ...

# %%
data = {
    'Name': ['Adilet', 'Arman', 'Sulu', 'Alisher', 'Aya'],
    'Age': [20, 21, 19, 22, 20],
    'Score': [85, 78, 92, 88, 75]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Score
# 0   Adilet   20     85
# 1    Arman   21     78
# 2     Sulu   19     92
# 3  Alisher   22     88
# 4      Aya   20     75

# %%
print(df.head(3))
print(df.describe())
print(df['Score'].mean())
# Out:
#      Name  Age  Score
# 0  Adilet   20     85
# 1   Arman   21     78
# 2    Sulu   19     92
#              Age      Score
# count   5.000000   5.000000
# mean   20.400000  83.600000
# std     1.140175   7.021396
# min    19.000000  75.000000
# 25%    20.000000  78.000000
# 50%    20.000000  85.000000
# 75%    21.000000  88.000000
# max    22.000000  92.000000
# 83.6

# %%
print(df[df['Age'] > 20])
print(df[df['Score'] > 80])
# Out:
#       Name  Age  Score
# 1    Arman   21     78
# 3  Alisher   22     88
#       Name  Age  Score
# 0   Adilet   20     85
# 2     Sulu   19     92
# 3  Alisher   22     88
